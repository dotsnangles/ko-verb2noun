# %%
import pandas as pd
from module.regularize import sentence_to_noun_verb

# %%
sheet_1 = 'data/eshc 인과관계 학습용(sample)_rev2.xlsx'
sheet_2 = 'data/port 인과관계 학습용(sample)_rev4.xlsx'
data_1 = pd.read_excel(sheet_1, names=[f'Col {i}' for i in range(10)])
data_2 = pd.read_excel(sheet_2, names=[f'Col {i}' for i in range(9)])

# %%
ce_chains_1 = data_1.iloc[:, 1:]
ce_chains_2 = data_2.iloc[:, 1:]

# %%
ce_chains_1
# Out:
#            Col 1    Col 2    Col 3     Col 4 Col 5 Col 6 Col 7 Col 8 Col 9
# 0     수직도 맞추는 작업  체인 끊어지며  체인 끊어지며  레버풀러에 맞음   NaN   NaN   NaN   NaN   NaN
# 1    전기 개폐기 교체작업  작업차에 깔림      NaN       NaN   NaN   NaN   NaN   NaN   NaN
# 2             인양       끼임      NaN       NaN   NaN   NaN   NaN   NaN   NaN
# 3      우오수로관로 설치   굴착면 붕괴   굴착면 붕괴        매몰   NaN   NaN   NaN   NaN   NaN
# 4        볼크 체결작업   중심을 잃고   중심을 잃고       떨어짐   NaN   NaN   NaN   NaN   NaN
# ..           ...      ...      ...       ...   ...   ...   ...   ...   ...
# 533      철스트랩 제거       끼임      NaN       NaN   NaN   NaN   NaN   NaN   NaN
# 534       벽 철거작업   벽체 넘어져   벽체 넘어져        깔림   NaN   NaN   NaN   NaN   NaN
# 535      비계 변경작업      떨어짐      NaN       NaN   NaN   NaN   NaN   NaN   NaN
# 536         살수작업   굴착기 깔려   굴착기 깔려        사망   NaN   NaN   NaN   NaN   NaN
# 537           이동      부딪힘      NaN       NaN   NaN   NaN   NaN   NaN   NaN
#
# [538 rows x 9 columns]

# %%
ce_chains_1.applymap(lambda x: sentence_to_noun_verb(x) if pd.isna(x) == False else x)
# Out:
#            Col 1    Col 2    Col 3     Col 4 Col 5 Col 6 Col 7 Col 8 Col 9
# 0     수직도 맞추는 작업   체인 끊어짐   체인 끊어짐  레버풀러에 맞음   NaN   NaN   NaN   NaN   NaN
# 1    전기 개폐기 교체작업  작업차에 깔림      NaN       NaN   NaN   NaN   NaN   NaN   NaN
# 2             인양       끼임      NaN       NaN   NaN   NaN   NaN   NaN   NaN
# 3      우오수로관로 설치  굴착이면 붕괴  굴착이면 붕괴        매몰   NaN   NaN   NaN   NaN   NaN
# 4        볼크 체결작업   중심을 잃음   중심을 잃음       떨어짐   NaN   NaN   NaN   NaN   NaN
# ..           ...      ...      ...       ...   ...   ...   ...   ...   ...
# 533      철스트랩 제거       끼임      NaN       NaN   NaN   NaN   NaN   NaN   NaN
# 534       벽 철거작업   벽체 넘어짐   벽체 넘어짐        깔림   NaN   NaN   NaN   NaN   NaN
# 535      비계 변경작업      떨어짐      NaN       NaN   NaN   NaN   NaN   NaN   NaN
# 536         살수작업   굴착기 깔림   굴착기 깔림        사망   NaN   NaN   NaN   NaN   NaN
# 537           이동      부딪힘      NaN       NaN   NaN   NaN   NaN   NaN   NaN
#
# [538 rows x 9 columns]

# %%
ce_chains_2
# Out:
#             Col 1          Col 2          Col 3    Col 4    Col 5 Col 6 Col 7  \
# 0        잡화 선적 작업  크레인 이동 보지 못하고  크레인 이동 보지 못하고  화물에 부딪혀  화물에 부딪혀    추락    추락
# 1        톤백 하역 작업             이동             이동       추락       추락    사망   NaN
# 2       열연코일 하역작업  사다리 손잡이 부러지면서  사다리 손잡이 부러지면서       추락       추락    골절    추락
# 3            하역작업      각목이 부러지면서      각목이 부러지면서       추락       추락    골절   NaN
# 4       선박엔지 선적작업       정반망사에 걸려       정반망사에 걸려       추락      NaN   NaN   NaN
# ..            ...            ...            ...      ...      ...   ...   ...
# 95      석탄하역 준비작업          의식 잃고           의식잃고       사망      NaN   NaN   NaN
# 96           하차작업          화물 붕괴          화물 붕괴       깔려       깔려    사망   NaN
# 97  정제염 톤백 재포장 작업          톤백 붕괴          톤백 붕괴   재해자 덮쳐   재해자 덮쳐    사망   NaN
# 98        현장 정리작업       모래 무너지면서       모래 무너지면서   바다에 빠져   바다에 빠져    익사   NaN
# 99       파이프에서 이동       발 미끄러지면서       발 미끄러지면서       탈골      NaN   NaN   NaN
#
#    Col 8
# 0     사망
# 1    NaN
# ...

# %%
ce_chains_2.applymap(lambda x: sentence_to_noun_verb(x) if pd.isna(x) == False else x)
# Out:
#             Col 1         Col 2         Col 3    Col 4    Col 5 Col 6 Col 7  \
# 0        잡화 선적 작업  크레인 이동 보지 못함  크레인 이동 보지 못함  화물에 부딪힘  화물에 부딪힘    추락    추락
# 1        톤백 하역 작업            이동            이동       추락       추락    사망   NaN
# 2       열연코일 하역작업   사다리 손잡이 부러짐   사다리 손잡이 부러짐       추락       추락    골절    추락
# 3            하역작업       각목이 부러짐       각목이 부러짐       추락       추락    골절   NaN
# 4       선박엔지 선적작업      정반망사에 걸림      정반망사에 걸림       추락      NaN   NaN   NaN
# ..            ...           ...           ...      ...      ...   ...   ...
# 95      석탄하역 준비작업         의식 잃음          의식잃음       사망      NaN   NaN   NaN
# 96           하차작업         화물 붕괴         화물 붕괴       깔림       깔림    사망   NaN
# 97  정제염 톤백 재포장 작업         톤백 붕괴         톤백 붕괴   재해자 덮침   재해자 덮침    사망   NaN
# 98        현장 정리작업        모래 무너짐        모래 무너짐   바다에 빠짐   바다에 빠짐    익사   NaN
# 99       파이프에서 이동        발 미끄러짐        발 미끄러짐       탈골      NaN   NaN   NaN
#
#    Col 8
# 0     사망
# 1    NaN
# 2    찰과상
# 3    NaN
# ...

# %%
ce_chains_1 = ce_chains_1.applymap(lambda x: sentence_to_noun_verb(x) if pd.isna(x) == False else x)
ce_chains_2 = ce_chains_2.applymap(lambda x: sentence_to_noun_verb(x) if pd.isna(x) == False else x)
